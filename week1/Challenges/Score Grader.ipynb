# %%
#Score Grader
mylist = [35,67,82,49,90,51,73,20]

for score in mylist:
    if score >= 50:
        print(f'your score is {score} you pass!')
    else:
        print(f'your score is {score} you fail!')
# Out:
# your score is 35 you fail!
# your score is 67 you pass!
# your score is 82 you pass!
# your score is 49 you fail!
# your score is 90 you pass!
# your score is 51 you pass!
# your score is 73 you pass!
# your score is 20 you fail!
