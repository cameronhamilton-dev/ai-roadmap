# %%
#Check status of device

devices = {
    "Laptop-01": "In use",
    "Laptop-02": "In repair",
    "Server-01": "Online",
    "Switch-01": "Offline",
    "Printer-01": "Online"
}

pairs=devices.items()

for device_name, status in devices.items():
    print(f'\nDevice Name: {device_name}\nStatus: {status}')
    if status in ['In repair' , 'Offline']:
        print('⚠ ACTION NEEDED')
# Out:
# Device Name: Laptop-01
# Status: In use
#
# Device Name: Laptop-02
# Status: In repair
# ⚠ ACTION NEEDED
#
# Device Name: Server-01
# Status: Online
#
# Device Name: Switch-01
# Status: Offline
# ⚠ ACTION NEEDED
#
# Device Name: Printer-01
# Status: Online

# %%
# Out:
# Device Name: Laptop-01
# Status: In use
# ⚠ ACTION NEEDED
#
# Device Name: Laptop-02
# Status: In repair
# ⚠ ACTION NEEDED
#
# Device Name: Server-01
# Status: Online
# ⚠ ACTION NEEDED
#
# Device Name: Switch-01
# Status: Offline
# ⚠ ACTION NEEDED
#
# Device Name: Printer-01
# Status: Online
# ⚠ ACTION NEEDED

# %%
pair[1]
# Out:
# 'Online'
